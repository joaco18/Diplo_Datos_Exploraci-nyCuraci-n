# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
import sys
in_colab = 'google.colab' in sys.modules

if in_colab:
  BASE_DIR = "https://github.com/DiploDatos/AnalisisYCuracion/raw/master/"
else:
  BASE_DIR = ".."

# %%
tabla_1 = pd.read_csv(BASE_DIR + "/input/wtageinf.csv")
tabla_1.head(10)
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
# 2    1     1.5  1.068796  4.879525  0.136479  3.614688  3.774849  4.020561
# 3    1     2.5  0.695974  5.672889  0.129678  4.342341  4.503255  4.754479
# 4    1     3.5  0.419815  6.391392  0.124717  4.992898  5.157412  5.416803
# 5    1     4.5  0.219867  7.041836  0.121040  5.575169  5.744752  6.013716
# 6    1     5.5  0.077506  7.630425  0.118271  6.096775  6.272175  6.551379
# 7    1     6.5 -0.021908  8.162951  0.116154  6.564430  6.745993  7.035656
# 8    1     7.5 -0.089441  8.644832  0.114510  6.984123  7.171952  7.472021
# 9    1     8.5 -0.133409  9.081120  0.113217  7.361236  7.555287  7.865533
#
#         P25       P50       P75        P90        P95        P97
# 0  3.150611  3.530203  3.879077   4.172493   4.340293   4.446488
# 1  3.597396  4.003106  4.387423   4.718161   4.910130   5.032625
# 2  4.428873  4.879525  5.327328   5.728153   5.967102   6.121929
# 3  5.183378  5.672889  6.175598   6.638979   6.921119   7.106250
# 4  5.866806  6.391392  6.942217   7.460702   7.781401   7.993878
# 5  6.484969  7.041836  7.635323   8.202193   8.556813   8.793444
# 6  7.043627  7.630425  8.262033   8.871384   9.255615   9.513307
# 7  7.548346  8.162951  8.828786   9.475466   9.885436  10.161350
# 8  8.004399  8.644832  9.341490  10.021014  10.453314  10.744924
# 9  8.416719  9.081120  9.805593  10.514064  10.965736  11.270838

# %%
tabla_1.dtypes
# Out:
# Sex         int64
# Agemos    float64
# L         float64
# M         float64
# S         float64
# P3        float64
# P5        float64
# P10       float64
# P25       float64
# P50       float64
# P75       float64
# P90       float64
# P95       float64
# P97       float64
# dtype: object

# %%
tabla_1.columns
# Out:
# Index(['Sex', 'Agemos', 'L', 'M', 'S', 'P3', 'P5', 'P10', 'P25', 'P50', 'P75',
#        'P90', 'P95', 'P97'],
#       dtype='object')

# %% [markdown]
# ### Ejercicio 1:
# ### Hacer un gráfico para niños y otro para niñas graficando todos los percentiles correspondientes para el peso en cada uno.

# %% [markdown]
# Percentiles para el peso de niños:
# - Descripción del dataset en la página: https://www.cdc.gov/growthcharts/percentile_data_files.htm
#   Weight-for-age charts, birth to 36 months, LMS parameters and selected smoothed weight percentiles
#   in kilograms, by sex and age.
# - Los parámetros LMS son la mediana (M), el coeficiente de variación generalizado (S) y la potencia
#   en la transformación de Box-Cox (L)

# %%
filtrado = tabla_1[tabla_1.Sex==1]
filtrado2 = tabla_1[tabla_1.Sex==2]
style=['--','--','--','--','k-','--','--','--','--','--']
fig, axes = plt.subplots(nrows=1, ncols=2)
filtrado.plot(x='Agemos',y=['P3','P5','P10','P25','P50','P75','P90','P95','P97'],style=style,
              title='Percentiles de pesos [kg] en niñas',ax=axes[0],figsize=(16,9),grid=True)
filtrado2.plot(x='Agemos',y=['P3','P5','P10','P25','P50','P75','P90','P95','P97'],style=style,
              title='Percentiles de pesos [kg] en niñas',ax=axes[1],figsize=(16,8),grid=True)

plt.show()

# %% [markdown]
# ### Ejercicio 2:
# ### Con los datos del archivo pasos.json hacer un gráfico de barras para cada provincia con la cantidad de pasos que tiene.

# %%
#Cargamos el archivo
tabla_pasos = pd.read_json(BASE_DIR + "/input/pasos.json")
tabla_pasos.head(5)
# Out:
#                      location                         name          province
# 0   [-54.832543, -68.3712885]   SAN SEBASTIAN  ( USHUAIA )  Tierra del Fuego
# 1  [-54.8249379, -68.3258626]      AERO PUBLICO DE USHUAIA  Tierra del Fuego
# 2  [-54.8096728, -68.3114748]  PUERTO USHUAIA (PREFECTURA)  Tierra del Fuego
# 3  [-54.8019121, -68.3029511]               PUERTO USHUAIA  Tierra del Fuego
# 4  [-51.6896359, -72.2993574]    PASO LAURITA CASAS VIEJAS        Santa Cruz

# %%
# Describimos los pasos por sus nombres para buscar repeticiones:
tabla_pasos.name.describe()
# Out:
# count                                                   252
# unique                                                  238
# top       AEROPUERTO INTERNACIONAL TENIENTE GENERAL BENJ...
# freq                                                      2
# Name: name, dtype: object

# %% [markdown]
# #### Podemos ver que hay pasos repetidos. Siempre se repiten dentro de la misma provincia? Porque en caso de que no fuera así, cuál se eliminaría, o a qué provincia se le asignaría el paso?

# %%
tabla_pasos[tabla_pasos.name.duplicated(keep=False)]
# Out:
#                        location  \
# 14   [-51.6117879, -69.3085038]
# 15   [-51.6117879, -69.3085038]
# 22   [-46.2752267, -71.7270022]
# 23   [-46.2752267, -71.7270022]
# 30   [-45.7894354, -67.4696871]
# 31   [-45.7894354, -67.4696871]
# 53    [-38.9521333, -68.142673]
# 54    [-38.9521333, -68.142673]
# 63   [-37.9341161, -57.5745361]
# 66    [-32.825277, -70.0729456]
# 68    [-32.825277, -70.0729456]
# 88   [-34.5580305, -58.4191975]
# 89   [-34.5580305, -58.4191975]
# 99   [-31.5718139, -68.4247562]
# 100  [-31.5718139, -68.4247562]
# 115  [-32.9168872, -60.7825792]
# 117  [-32.9168872, -60.7825792]
# 122  [-31.3154367, -64.2145085]
# 125  [-31.3154367, -64.2145085]
# 128   [-29.1156361, -56.554963]
# 129   [-29.1156361, -56.554963]
# 135  [-32.2149531, -58.1378887]
# 136  [-32.2165573, -58.1470583]
# 158  [-26.8358881, -65.1105502]
# 159  [-26.8358881, -65.1105502]
# 227  [-37.9341161, -57.5745361]
# 249  [-34.1176359, -57.9897668]
# 250  [-34.1176359, -57.9897668]
#
#                                                   name  \
# 14                                   AERO RIO GALLEGOS
# 15                                   AERO RIO GALLEGOS
# 22                          ING. PALLAVICINI - IBAÃ‘EZ
# 23                          ING. PALLAVICINI - IBAÃ‘EZ
# 30                             AERO COMODORO RIVADAVIA
# 31                             AERO COMODORO RIVADAVIA
# 53                                        AERO NEUQUEN
# 54                                        AERO NEUQUEN
# 63                                  AERO MAR DEL PLATA
# 66                      CRISTO REDENTOR (LIBERTADORES)
# 68                      CRISTO REDENTOR (LIBERTADORES)
# 88                                  AERO JORGE NEWBERY
# 89                                  AERO JORGE NEWBERY
# 99                                       AERO SAN JUAN
# 100                                      AERO SAN JUAN
# 115                                       AERO ROSARIO
# 117                                       AERO ROSARIO
# 122                                       AERO CORDOBA
# 125                                       AERO CORDOBA
# 128                                      PUERTO ALVEAR
# 129                                      PUERTO ALVEAR
# 135                                       PUERTO COLON
# 136                                       PUERTO COLON
# 158  AEROPUERTO INTERNACIONAL TENIENTE GENERAL BENJ...
# 159  AEROPUERTO INTERNACIONAL TENIENTE GENERAL BENJ...
# 227                                 AERO MAR DEL PLATA
# 249                                        ROU COLONIA
# 250                                        ROU COLONIA
#
#                                               province
# 14                                          Santa Cruz
# 15   AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO...
# 22                                          Santa Cruz
# 23                                          Santa Cruz
# 30                                              Chubut
# 31                                              Chubut
# 53                                             Neuquen
# 54                                             Neuquen
# 63                                        Buenos Aires
# 66                                             Mendoza
# 68                                             Mendoza
# 88                                        Buenos Aires
# 89                                        Buenos Aires
# 99                                            San Juan
# 100                                           San Juan
# 115                                           Santa Fe
# 117                                           Santa Fe
# 122                                            Cordoba
# 125                                            Cordoba
# 128                                         Entre Rios
# 129                                         Entre Rios
# 135                                           Santa Fe
# 136                                           Santa Fe
# 158                                            Tucuman
# 159                                            Tucuman
# 227                                       Buenos Aires
# 249                                       Buenos Aires
# 250                                       Buenos Aires

# %% [markdown]
# ##### Se comprueba que salvo el caso en que está mál escrito el nombre de la provincia,siempre se repiten dentro de la misma provincia.

# %% [markdown]
# #### Ahora deberíamos ver si no hay más de un paso que tenga la misma posición pero que figure con más de un nombre:

# %%
coord = tabla_pasos['location'].apply(pd.Series) # Transforma la columna con arrays en dos columnas distintas 
coord = coord.rename(columns = lambda x : 'coord_' + str(x))
tabla_pasos = pd.concat([tabla_pasos[:], coord[:]], axis=1)
tabla_pasos[coord.duplicated(keep=False)]
# Out:
#                        location  \
# 14   [-51.6117879, -69.3085038]
# 15   [-51.6117879, -69.3085038]
# 22   [-46.2752267, -71.7270022]
# 23   [-46.2752267, -71.7270022]
# 30   [-45.7894354, -67.4696871]
# 31   [-45.7894354, -67.4696871]
# 32   [-45.7894354, -67.4696871]
# 38   [-41.1467101, -71.1642129]
# 45   [-40.1133859, -71.6806031]
# 53    [-38.9521333, -68.142673]
# 54    [-38.9521333, -68.142673]
# 63   [-37.9341161, -57.5745361]
# 64   [-34.2405546, -69.8305781]
# 65   [-34.2405546, -69.8305781]
# 66    [-32.825277, -70.0729456]
# 68    [-32.825277, -70.0729456]
# 69   [-32.8278642, -68.8006789]
# 72   [-34.8150044, -58.5370171]
# 73   [-34.8150044, -58.5370171]
# 74   [-34.8150044, -58.5370171]
# 88   [-34.5580305, -58.4191975]
# 89   [-34.5580305, -58.4191975]
# 90   [-34.4747015, -58.6145741]
# 92   [-34.4747015, -58.6145741]
# 99   [-31.5718139, -68.4247562]
# 100  [-31.5718139, -68.4247562]
# 115  [-32.9168872, -60.7825792]
# 117  [-32.9168872, -60.7825792]
# 120  [-32.7161131, -60.7314613]
# 121  [-32.7161131, -60.7314613]
# ..                          ...
# 131  [-31.7088748, -60.8100047]
# 138  [-29.3838767, -66.7963367]
# 139  [-29.3838767, -66.7963367]
# 143  [-32.8278642, -68.8006789]
# 149      [-23.2375, -67.076389]
# 153     [-27.7575812, -64.3032]
# 155     [-27.7575812, -64.3032]
# 156  [-27.5063076, -64.9352342]
# 158  [-26.8358881, -65.1105502]
# 159  [-26.8358881, -65.1105502]
# 185  [-27.5711373, -54.6822256]
# 186  [-27.5711373, -54.6822256]
# 190    [-27.294403, -54.227733]
# 191    [-27.294403, -54.227733]
# 194   [-26.216682, -58.2327793]
# 197  [-24.8442303, -65.4806004]
# 199  [-24.8442303, -65.4806004]
# 209  [-25.3726325, -57.6514475]
# 210  [-25.3726325, -57.6514475]
# 220      [-23.2375, -67.076389]
# 224  [-41.1467101, -71.1642129]
# 225   [-26.216682, -58.2327793]
# 227  [-37.9341161, -57.5745361]
# 230  [-31.7088748, -60.8100047]
# 232  [-27.5063076, -64.9352342]
# 234   [-32.825277, -70.0729456]
# 235   [-32.825277, -70.0729456]
# 239  [-40.1133859, -71.6806031]
# 249  [-34.1176359, -57.9897668]
# 250  [-34.1176359, -57.9897668]
#
#                                                   name  \
# 14                                   AERO RIO GALLEGOS
# 15                                   AERO RIO GALLEGOS
# 22                          ING. PALLAVICINI - IBAÃ‘EZ
# 23                          ING. PALLAVICINI - IBAÃ‘EZ
# 30                             AERO COMODORO RIVADAVIA
# 31                             AERO COMODORO RIVADAVIA
# 32    AEROPUERTO INTERNACIONAL GENERAL ENRIQUE MOSCONI
# 38   AEROPUERTO INTERNACIONAL TENIENTE LUIS CANDELA...
# 45                                      PASO HUA - HUM
# 53                                        AERO NEUQUEN
# 54                                        AERO NEUQUEN
# 63                                  AERO MAR DEL PLATA
# 64                                PASO CAJON DEL MAIPO
# 65                          PASO PORTILLO DE PIUQUENES
# 66                      CRISTO REDENTOR (LIBERTADORES)
# 68                      CRISTO REDENTOR (LIBERTADORES)
# 69   AEROPUERTO INTERNACIONAL GOBERNADOR FRANCISCO ...
# 72                                         AERO EZEIZA
# 73                                   AERO EZEIZA - FBO
# 74         AEROPUERTO INTERNACIONAL MINISTRO PISTARINI
# 88                                  AERO JORGE NEWBERY
# 89                                  AERO JORGE NEWBERY
# 90                                   AERO DON TORCUATO
# 92                                   AERO SAN FERNANDO
# 99                                       AERO SAN JUAN
# 100                                      AERO SAN JUAN
# 115                                       AERO ROSARIO
# 117                                       AERO ROSARIO
# 120                                  PUERTO SAN MARTIN
# 121                             PUERTO SAN MARTIN (PF)
# ..                                                 ...
# 131                          AEROPUERTO DE SAUCE VIEJO
# 138                                      AERO LA RIOJA
# 139                   AEROPUERTO DE TUCUMAN / LA RIOJA
# 143                                       AERO MENDOZA
# 149                                         JAMA NORTE
# 153                                      AERO SANTIAGO
# 155                           AERO SANTIAGO DEL ESTERO
# 156       AEROPUERTO INTERNACIONAL TERMAS DE RIO HONDO
# 158  AEROPUERTO INTERNACIONAL TENIENTE GENERAL BENJ...
# 159  AEROPUERTO INTERNACIONAL TENIENTE GENERAL BENJ...
# 185                                  PUERTO ALBA POSSE
# 186                             PUERTO ALBA POSSE (PF)
# 190                            EL SOBERBIO - P.SOBERBO
# 191                       EL SOBERBIO - P.SOBERBO (PF)
# 194                AEROPUERTO INTERNACIONAL DE FORMOSA
# 197   AEROPUERTO INTERNACIONAL MARTIN MIGUEL DE GUEMES
# 199                                         AERO SALTA
# 209                                   PUERTO PILCOMAYO
# 210                              PUERTO PILCOMAYO (PF)
# 220                                       PASO DE JAMA
# 224                                     AERO BARILOCHE
# 225                                       AERO FORMOSA
# 227                                 AERO MAR DEL PLATA
# 230                                   AERO SAUCE VIEJO
# 232                              AERO TERMAS RIO HONDO
# 234                         CRISTO REDENTOR (HORCONES)
# 235                     CRISTO REDENTOR PUNTA DE VACAS
# 239                                  HUA HUM (FLUVIAL)
# 249                                        ROU COLONIA
# 250                                        ROU COLONIA
#
#                                               province    coord_0    coord_1
# 14                                          Santa Cruz -51.611788 -69.308504
# 15   AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO... -51.611788 -69.308504
# 22                                          Santa Cruz -46.275227 -71.727002
# 23                                          Santa Cruz -46.275227 -71.727002
# 30                                              Chubut -45.789435 -67.469687
# 31                                              Chubut -45.789435 -67.469687
# 32                                              Chubut -45.789435 -67.469687
# 38                                           Rio Negro -41.146710 -71.164213
# 45                                             Neuquen -40.113386 -71.680603
# 53                                             Neuquen -38.952133 -68.142673
# 54                                             Neuquen -38.952133 -68.142673
# 63                                        Buenos Aires -37.934116 -57.574536
# 64                                             Mendoza -34.240555 -69.830578
# 65                                             Mendoza -34.240555 -69.830578
# 66                                             Mendoza -32.825277 -70.072946
# 68                                             Mendoza -32.825277 -70.072946
# 69                                             Mendoza -32.827864 -68.800679
# 72                                        Buenos Aires -34.815004 -58.537017
# 73                                        Buenos Aires -34.815004 -58.537017
# 74                                        Buenos Aires -34.815004 -58.537017
# 88                                        Buenos Aires -34.558031 -58.419198
# 89                                        Buenos Aires -34.558031 -58.419198
# 90                                        Buenos Aires -34.474702 -58.614574
# 92                                        Buenos Aires -34.474702 -58.614574
# 99                                            San Juan -31.571814 -68.424756
# 100                                           San Juan -31.571814 -68.424756
# 115                                           Santa Fe -32.916887 -60.782579
# 117                                           Santa Fe -32.916887 -60.782579
# 120                                           Santa Fe -32.716113 -60.731461
# 121                                           Santa Fe -32.716113 -60.731461
# ..                                                 ...        ...        ...
# 131                                         Entre Rios -31.708875 -60.810005
# 138                                           La Rioja -29.383877 -66.796337
# 139                                           La Rioja -29.383877 -66.796337
# 143                                            Mendoza -32.827864 -68.800679
# 149                                          Catamarca -23.237500 -67.076389
# 153                                Santiago del Estero -27.757581 -64.303200
# 155                                Santiago del Estero -27.757581 -64.303200
# 156                                Santiago del Estero -27.506308 -64.935234
# 158                                            Tucuman -26.835888 -65.110550
# 159                                            Tucuman -26.835888 -65.110550
# 185                                           Misiones -27.571137 -54.682226
# 186                                           Misiones -27.571137 -54.682226
# 190                                           Misiones -27.294403 -54.227733
# 191                                           Misiones -27.294403 -54.227733
# 194                                            Formosa -26.216682 -58.232779
# 197                                              Salta -24.844230 -65.480600
# 199                                              Salta -24.844230 -65.480600
# 209                                            Formosa -25.372633 -57.651448
# 210                                            Formosa -25.372633 -57.651448
# 220                                              Jujuy -23.237500 -67.076389
# 224                                          Rio Negro -41.146710 -71.164213
# 225                                            Formosa -26.216682 -58.232779
# 227                                       Buenos Aires -37.934116 -57.574536
# 230                                           Santa Fe -31.708875 -60.810005
# 232                                Santiago del Estero -27.506308 -64.935234
# 234                                            Mendoza -32.825277 -70.072946
# 235                                            Mendoza -32.825277 -70.072946
# 239                                            Neuquen -40.113386 -71.680603
# 249                                       Buenos Aires -34.117636 -57.989767
# 250                                       Buenos Aires -34.117636 -57.989767
#
# [64 rows x 5 columns]

# %%
print('Número de repeticiones por "location": '+ str(tabla_pasos.location[coord.duplicated()].count()))
# Out:
# Número de repeticiones por "location": 34

# %% [markdown]
# #### Vemos que hay 34 repeticiones dadas por coordenadas (que pueden o no coincidir con algunas o todas de las repeticiones por nombre)

# %%
# Describimos los pasos por las provincias a las que pertenecen:
tabla_pasos.province.describe()
# Out:
# count              252
# unique              25
# top       Buenos Aires
# freq                48
# Name: province, dtype: object

# %% [markdown]
# #### En Argentina hay 23 provincias, por lo que el dataset tiene algún error.

# %%
list(tabla_pasos.province.unique())
# Out:
# ['Tierra del Fuego',
#  'Santa Cruz',
#  'AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ',
#  'Chubut',
#  'Rio Negro',
#  'Neuquen',
#  'NEUQUEN',
#  'Buenos Aires',
#  'Mendoza',
#  'San Luis',
#  'San Juan',
#  'Santa Fe',
#  'CÃ³rdoba',
#  'Cordoba',
#  'Entre Rios',
#  'La Rioja',
#  'Corrientes',
#  'Catamarca',
#  'Santiago del Estero',
#  'Tucuman',
#  'Chaco',
#  'Misiones',
#  'Formosa',
#  'Salta',
#  'Jujuy']

# %% [markdown]
# #### Se puede ver los siguientes problemas en los datos:
# - 'AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ' figura como una provincia
# - Neuquén aparece en mayúscula y minúscula, lo que se toma como dos provincias distintas
# - Córdoba con y sin aceto son tomadas como provincias distintas (y en el caso con acento importada erroneamente)
# - No figura La Pampa (no sería a priori un error, pero sí algo a remarcar al usuario/dueño de los datos)

# %% [markdown]
# #### Limpieza de los datos:

# %%
# Se elimina 'AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ'
tabla_pasos_c = tabla_pasos[tabla_pasos.province != 'AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ']
# Se corrijen los nombres:
tabla_pasos_c = tabla_pasos_c.replace({'NEUQUEN': 'Neuquen', 'CÃ³rdoba': 'Cordoba'})
tabla_pasos_c.province.describe()
# Out:
# count              251
# unique              22
# top       Buenos Aires
# freq                48
# Name: province, dtype: object

# %% [markdown]
# #### Se eliminan los pasos eliminados por location sin considerar cual nombre particular dejamos, porque no es un dato relevante a nuestro problema que es determinar el número de pasos por provincia. En todo caso habría que determinar un criterio de si se deja el nombre genérico o el nombre propio de cada paso (ej: Aero Comodoro Rivadavia vs. Aeropuerto Internacional General Enrique Mosconi)

# %%
# Se eliminan los pasos duplicados por coordenadas:
tabla_sinrep = tabla_pasos_c[~tabla_pasos_c[['coord_0','coord_1']].duplicated()]

tabla_sinrep[(tabla_sinrep['name'].duplicated(keep=False))]
# Out:
#                        location          name  province    coord_0    coord_1
# 135  [-32.2149531, -58.1378887]  PUERTO COLON  Santa Fe -32.214953 -58.137889
# 136  [-32.2165573, -58.1470583]  PUERTO COLON  Santa Fe -32.216557 -58.147058

# %% [markdown]
#  #### Vemos que aún eliminando los duplicados por locación queda un paso que está duplicado por nombre y que tiene dos locaciones distintas.

# %%
# Se eliminan los pasos repetidos por nombre:
tabla_sinrep = tabla_sinrep[~(tabla_sinrep['name'].duplicated())]

# Se verifica que coincidan el número de nombres y localizaciones únicas (sin repeticiones) por provincia:
tabla_sinrep.groupby('province')['name','location'].nunique()
# Out:
#                      name  location
# province
# Buenos Aires           42        42
# Catamarca               3         3
# Chaco                   3         3
# Chubut                 13        13
# Cordoba                 3         3
# Corrientes             15        15
# Entre Rios             12        12
# Formosa                 9         9
# Jujuy                   7         7
# La Rioja                2         2
# Mendoza                 9         9
# Misiones               36        36
# Neuquen                 9         9
# Rio Negro               7         7
# Salta                   3         3
# San Juan                4         4
# San Luis                2         2
# Santa Cruz             19        19
# Santa Fe                7         7
# Santiago del Estero     2         2
# Tierra del Fuego        9         9
# Tucuman                 1         1

# %%
# Se crea la tabla a graficar:
n_pasos = tabla_sinrep.groupby('province')['name'].nunique()
n_pasos = n_pasos.to_frame()
n_pasos =n_pasos.reset_index()
n_pasos = n_pasos.rename(columns = {'province':'Provincias','name': 'Número de pasos'})
n_pasos.head(5)
# Out:
#      Provincias  Número de pasos
# 0  Buenos Aires               42
# 1     Catamarca                3
# 2         Chaco                3
# 3        Chubut               13
# 4       Cordoba                3

# %%
import seaborn as sns

# Se grafica:
plt.figure(figsize=(15,6))
plt.title('Número de pasos internacionales por provincia de Argentina')
sns.barplot(data=n_pasos,x='Provincias', y='Número de pasos',color='pink')
sns.despine()
plt.xticks(rotation=45)
plt.show()
